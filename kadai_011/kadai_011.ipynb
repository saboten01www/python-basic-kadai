# %%
array = ["水","金","地","火","木","土","天","海","冥"]

#forループで水～冥の9行を表示
for plant in array:
    print(plant)

#インデックスを初期化
i = 0

#whileループで水～冥の9行を表示
while i < len(array):
    print(array[i])
    i += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
