# %%
from typing import AsyncGenerator

class Human:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def print_info(self):
    print(f"Name: {self.name}, Age: {self.age}")

taro = Human("samraitaro",30)
taro.print_info()
# Out:
# Name: samraitaro, Age: 30
